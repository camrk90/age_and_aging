# %%
import pandas as pd
import readfcs
import pytometry as pm

# %%
#Set working path
path_main="/Users/cameronkelsey/Documents/smack_lab/cayo_data/flow_cytometry/"

print(f'{path_main}trapping_2022.0001.fcs')
# Out:
# /Users/cameronkelsey/Documents/smack_lab/cayo_data/flow_cytometry/trapping_2022.0001.fcs

# %%
pm.io.read_fcs(f'{path_main}trapping_2024_0C3.0001.fcs', ignore_offset_error=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pm.io.read_fcs(f'{path_main}trapping_2024_0C3.0001.fcs', ignore_offset_error=True)
#
# TypeError: read_fcs() got an unexpected keyword argument 'ignore_offset_error'
